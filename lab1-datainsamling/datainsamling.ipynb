# %%
import pandas as pd
kalori = pd.read_csv('övningsdata.csv')

df= pd.DataFrame(kalori)
df.head()
# Out:
#          Date  Steps  Calories_Burned
# 0  2025-01-01  10993              421
# 1  2025-01-02   9723              334
# 2  2025-01-03  11295              365
# 3  2025-01-04  13046              479
# 4  2025-01-05   9531              465

# %%
data = { "city":["Stockholm","Göteborg","Malmö"],"temp":[10,17,20], "date":["2024-06-01","2024-06-01","2024-06-01"] }
df2 = pd.DataFrame(data)
df2.head()
# Out:
#         city  temp        date
# 0  Stockholm    10  2024-06-01
# 1   Göteborg    17  2024-06-01
# 2      Malmö    20  2024-06-01

# %%
data = {
    "kund_id": [101, 102, 103, 101, 104, 105, 106, 107, 108, 109],
    "datum": [
        "2024-12-28", "2025-01-02", "2025-01-03", "2025-01-05",
        "2025-01-06", "2025-01-08", "2025-01-08", "2025-01-09",
        "2025-01-10", "2025-01-10"
    ],
    "produkt": [
        "Laptop", "Mobilskal", "Hörlurar", "Mus", "Tangentbord",
        "Skärm", "Mobiltelefon", "Webbkamera", "Skrivare", "USB-minne"
    ],
    "kategori": [
        "Elektronik", "Tillbehör", "Ljud", "Tillbehör", "Tillbehör",
        "Elektronik", "Elektronik", "Tillbehör", "Elektronik", "Tillbehör"
    ],
    "pris": [12000, 199, 899, 349, 499, 2200, 8500, 699, 1499, 129],
    "antal": [1, 2, 1, 1, 1, 2, 1, 3, 1, 4],
    "stad": [
        "Stockholm", "Göteborg", "Malmö", "Stockholm", "Uppsala",
        "Stockholm", "Lund", "Göteborg", "Umeå", "Västerås"
    ]
}

df = pd.DataFrame(data)
df.head()
df.describe()
# Out:
#           kund_id          pris     antal
# count   10.000000     10.000000  10.00000
# mean   104.600000   2697.300000   1.70000
# std      2.875181   4113.751655   1.05935
# min    101.000000    129.000000   1.00000
# 25%    102.250000    386.500000   1.00000
# 50%    104.500000    799.000000   1.00000
# 75%    106.750000   2024.750000   2.00000
# max    109.000000  12000.000000   4.00000

# %%
df = df[(df["stad"] == "Stockholm") & (df["datum"] >= "2024-01-01")]
df.head()
# Out:
#    kund_id       datum produkt    kategori   pris  antal       stad
# 0      101  2024-12-28  Laptop  Elektronik  12000      1  Stockholm
# 3      101  2025-01-05     Mus   Tillbehör    349      1  Stockholm
# 5      105  2025-01-08   Skärm  Elektronik   2200      2  Stockholm

# %%
df.describe()
# Out:
#           kund_id          pris     antal
# count    3.000000      3.000000  3.000000
# mean   102.333333   4849.666667  1.333333
# std      2.309401   6261.150081  0.577350
# min    101.000000    349.000000  1.000000
# 25%    101.000000   1274.500000  1.000000
# 50%    101.000000   2200.000000  1.000000
# 75%    103.000000   7100.000000  1.500000
# max    105.000000  12000.000000  2.000000

# %%
# Visa färre decimaler
df.describe().round(2)
# Out:
#        kund_id      pris  antal
# count    10.00     10.00  10.00
# mean    104.60   2697.30   1.70
# std       2.88   4113.75   1.06
# min     101.00    129.00   1.00
# 25%     102.25    386.50   1.00
# 50%     104.50    799.00   1.00
# 75%     106.75   2024.75   2.00
# max     109.00  12000.00   4.00

# %%
import pandas as pd
csv_path = "data\smart_home_energy_consumption_large.csv"
df = pd.read_csv(csv_path)
df.head(30)
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\s'
# <>:2: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\marya\AppData\Local\Temp\ipykernel_30516\1230364175.py:2: SyntaxWarning: invalid escape sequence '\s'
#   csv_path = "data\smart_home_energy_consumption_large.csv"
#     Home ID    Appliance Type  Energy Consumption (kWh)   Time        Date  \
# 0        94            Fridge                      0.20  21:12  2023-12-02
# 1       435              Oven                      0.23  20:11  2023-08-06
# 2       466        Dishwasher                      0.32  06:39  2023-11-21
# 3       496            Heater                      3.92  21:56  2023-01-21
# 4       137         Microwave                      0.44  04:31  2023-08-26
# 5        68  Air Conditioning                      4.68  11:36  2023-05-06
# 6       237          Computer                      0.25  12:05  2023-06-06
# 7       329  Air Conditioning                      3.50  03:34  2023-12-12
# ...

# %%
df_student= pd.read_csv("data\StudentPerformanceFactors.csv")
df_student.head(30)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\S'
# <>:1: SyntaxWarning: invalid escape sequence '\S'
# C:\Users\marya\AppData\Local\Temp\ipykernel_30516\3804701900.py:1: SyntaxWarning: invalid escape sequence '\S'
#   df_student= pd.read_csv("data\StudentPerformanceFactors.csv")
#     Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0              23          84                  Low                High
# 1              19          64                  Low              Medium
# 2              24          98               Medium              Medium
# 3              29          89                  Low              Medium
# 4              19          92               Medium              Medium
# 5              19          88               Medium              Medium
# 6              29          84               Medium                 Low
# 7              25          78                  Low                High
# ...

# %%
# Undersök smart home dataset
import pandas as pd
df_smart = pd.read_csv("data/smart_home_energy_consumption_large.csv")
print("Smart Home Dataset:")
print(f"Shape: {df_smart.shape}")
print(f"Columns: {list(df_smart.columns)}")
print("\nFirst 5 rows:")
df_smart.head()
# Out:
# Smart Home Dataset:
# Shape: (100000, 8)
# Columns: ['Home ID', 'Appliance Type', 'Energy Consumption (kWh)', 'Time', 'Date', 'Outdoor Temperature (°C)', 'Season', 'Household Size']
#
# First 5 rows:
#    Home ID Appliance Type  Energy Consumption (kWh)   Time        Date  \
# 0       94         Fridge                      0.20  21:12  2023-12-02
# 1      435           Oven                      0.23  20:11  2023-08-06
# 2      466     Dishwasher                      0.32  06:39  2023-11-21
# 3      496         Heater                      3.92  21:56  2023-01-21
# 4      137      Microwave                      0.44  04:31  2023-08-26
#
#    Outdoor Temperature (°C)  Season  Household Size
# 0                      -1.0    Fall               2
# 1                      31.1  Summer               5
# 2                      21.3    Fall               3
# 3                      -4.2  Winter               1
# 4                      34.5  Summer               5

# %%
# Undersök student dataset
df_student = pd.read_csv("data/StudentPerformanceFactors.csv")
print("Student Performance Dataset:")
print(f"Shape: {df_student.shape}")
print(f"Columns: {list(df_student.columns)}")
print("\nFirst 5 rows:")
df_student.head()
# Out:
# Student Performance Dataset:
# Shape: (6607, 20)
# Columns: ['Hours_Studied', 'Attendance', 'Parental_Involvement', 'Access_to_Resources', 'Extracurricular_Activities', 'Sleep_Hours', 'Previous_Scores', 'Motivation_Level', 'Internet_Access', 'Tutoring_Sessions', 'Family_Income', 'Teacher_Quality', 'School_Type', 'Peer_Influence', 'Physical_Activity', 'Learning_Disabilities', 'Parental_Education_Level', 'Distance_from_Home', 'Gender', 'Exam_Score']
#
# First 5 rows:
#    Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0             23          84                  Low                High
# 1             19          64                  Low              Medium
# 2             24          98               Medium              Medium
# 3             29          89                  Low              Medium
# 4             19          92               Medium              Medium
#
#   Extracurricular_Activities  Sleep_Hours  Previous_Scores Motivation_Level  \
# ...

# %%
df_student.isnull().sum()
# Out:
# Hours_Studied                  0
# Attendance                     0
# Parental_Involvement           0
# Access_to_Resources            0
# Extracurricular_Activities     0
# Sleep_Hours                    0
# Previous_Scores                0
# Motivation_Level               0
# Internet_Access                0
# Tutoring_Sessions              0
# Family_Income                  0
# Teacher_Quality               78
# School_Type                    0
# Peer_Influence                 0
# Physical_Activity              0
# Learning_Disabilities          0
# Parental_Education_Level      90
# Distance_from_Home            67
# Gender                         0
# Exam_Score                     0
# dtype: int64
